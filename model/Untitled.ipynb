# %%
import pandas as pd

# %%
frame = []
with open('sample.txt') as f:
    line = f.readlines()[9:50000]
    for l in line:
        frame.append(list(map(float, (l.rstrip('\n').split('\t')[1:]))))

# %%
index, columns, value = zip(*frame)

# %%
# df = pd.DataFrame(index=range(4,201), columns=range(5,int(max(columns))+1))
df = pd.DataFrame(index=list(map(str, range(4, 201))), columns=list(map(str, range(5,513))))

# %%
for i, c, v in zip(index, columns, value):
    idx, col = str(int(c-i)), str(int(c))
    df[col][idx] = v

# %%
df
# Out:
#        5         6    7         8         9        10        11        12  \
# 4    0.0       0.0  0.0  0.000076       0.0       0.0  0.001964       0.0
# 5    NaN  0.000067  0.0       0.0  0.000576  0.000016       0.0       0.0
# 6    NaN       NaN  0.0   0.00017       0.0       0.0  0.000855  0.001954
# 7    NaN       NaN  NaN       0.0  0.000578  0.000335       0.0       0.0
# 8    NaN       NaN  NaN       NaN       0.0       0.0  0.000087  0.000869
# ..   ...       ...  ...       ...       ...       ...       ...       ...
# 197  NaN       NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 198  NaN       NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 199  NaN       NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 200  NaN       NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 201  NaN       NaN  NaN       NaN       NaN       NaN       NaN       NaN
#
#            13        14  ...       347       348       349       350  \
# ...

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
import pickle
# ここから自作
import model
import result
import mode
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
inp = torch.tensor(pickle.load(open("../data/make/maxspan100/seq_1.pkl","rb")))
tar = torch.tensor(pickle.load(open("../data/make/maxspan100/target_1.pkl","rb"))).float()
tar = torch.flip(tar, dims=[1])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
inp = inp[:500].reshape(100, 512, 5)

# %%
L, N, Hin = 512, 100000, 5
layer, Hout = 2, 15

h0 = torch.randn(2*layer, N, Hout)
c0 = torch.randn(2*layer, N, Hout)

lstm = nn.LSTM(Hin, Hout, layer, batch_first=True, bidirectional=True)

out, (h, c) = lstm(inp)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_112250/3307391644.py in <module>
#       7 lstm = nn.LSTM(Hin, Hout, layer, batch_first=True, bidirectional=True)
#       8
# ----> 9 out, (h, c) = lstm(inp)
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     690         if batch_sizes is None:
# ...

# %%
rnn = nn.LSTM(10, 30, 6)

input = torch.randn(5, 3, 10)
h0 = torch.randn(6, 3, 30)
c0 = torch.randn(6, 3, 30)

output, (hn, cn) = rnn(input, (h0, c0))

# %%
output.shape
# Out:
# torch.Size([5, 3, 30])

# %%
hn.shape
# Out:
# torch.Size([4, 3, 30])

# %%
cn.shape
# Out:
# torch.Size([4, 3, 30])
